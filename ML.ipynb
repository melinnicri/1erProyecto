# %% [markdown]
# Machine learning Sistema de Recomendación

# %%
# Importar librerías
import csv
import pandas as pd
import json
import numpy as np
import ast
import sklearn as sk
from sklearn.metrics.pairwise import cosine_similarity

from sklearn.preprocessing import StandardScaler
import scipy.sparse as sp

import operator

# %%
#Abrir archivo .csv a dataframe
df_2 = pd.read_csv('Third_Users.csv', encoding = "latin-1")

# %%
#Ver nombres de columnas
df_2.columns
# Out:
# Index(['user_id', 'items_count', 'steam_id', 'item_id', 'item_name',
#        'playtime_forever'],
#       dtype='object')

# %%
# Dataframe con las columnas de usuario, nombre de juego y tiempo de juego (en minutos)
user_name_time = df_2[["user_id", "item_name", "playtime_forever"]]

# %%
# Descripción estadística de los playtime_forever (en minutos)
user_name_time.describe()
# Out:
#        playtime_forever
# count      5.153209e+06
# mean       9.914951e+02
# std        5.418204e+03
# min        0.000000e+00
# 25%        0.000000e+00
# 50%        3.400000e+01
# 75%        3.550000e+02
# max        6.427730e+05

# %% [markdown]
# En este caso de los playtime_forever, hay una media de 9,9 x 10 a la 2 minutos, 990 minutos (16,5 horas) +/- 5,4 x 10 a la 3, 5400 minutos (90 horas).
# Bajo el 75% de los usuarios, juegan 3,5 x 10 a la 2 minutos, 350 minutos (5,83 horas).

# %%
# Ver data
user_name_time
# Out:
#                    user_id                      item_name  playtime_forever
# 0        76561197970982479                 Counter-Strike                 6
# 1        76561197970982479          Team Fortress Classic                 0
# 2        76561197970982479                  Day of Defeat                 7
# 3        76561197970982479             Deathmatch Classic                 0
# 4        76561197970982479      Half-Life: Opposing Force                 0
# ...                    ...                            ...               ...
# 5153204  76561198329548331                   BrainBread 2                 0
# 5153205  76561198329548331                    All Is Dust                 0
# 5153206  76561198329548331  One Way To Die: Steam Edition                 3
# 5153207  76561198329548331          You Have 10 Seconds 2                 4
# 5153208  76561198329548331                     Minds Eyes                 3
#
# [5153209 rows x 3 columns]

# %%
# Cambiar tipo de dato y rellenar con 0
user_name_time["playtime_forever"] = user_name_time["playtime_forever"].fillna(0).astype("int32")
# Out:
# C:\Users\56988\AppData\Local\Temp\ipykernel_8448\1075371503.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_name_time["playtime_forever"] = user_name_time["playtime_forever"].fillna(0).astype("int32")

# %%
# Info de data
user_name_time.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5153209 entries, 0 to 5153208
# Data columns (total 3 columns):
#  #   Column            Dtype
# ---  ------            -----
#  0   user_id           object
#  1   item_name         object
#  2   playtime_forever  int32
# dtypes: int32(1), object(2)
# memory usage: 98.3+ MB

# %%
# Obtenemos una tabla con registros unicos de cada juego
unique_item_ids = user_name_time.drop_duplicates(subset="item_name")

# %%
# Reducimos el data por una cuestión de espacio, pero sin que afecte la calidad de los datos
df_modelo = unique_item_ids.sample(frac=0.125, random_state=1)

# %%
# Primero se comienza creando la tabla pivote user versus item_name
piv_table = df_modelo.pivot(index=["user_id"], columns=["item_name"], values="playtime_forever").fillna(0)
piv_table
# Out:
# item_name     1... 2... 3... KICK IT! (Drop That Beat Like an Ugly Baby)  \
# user_id
# 12549                                                       0.0
# 13lazer                                                     0.0
# 1920410                                                     0.0
# 19702316748                                                 0.0
# 2d4nk4m3                                                    0.0
# ...                                                         ...
# wswanderer81                                                0.0
# wyvaud                                                      0.0
# xexilex                                                     0.0
# xfluttersx                                                  0.0
# yookobz                                                     0.0
#
# item_name     10,000,000  12 Labours of Hercules IV: Mother Nature  \
# user_id
# 12549                0.0                                       0.0
# 13lazer              0.0                                       0.0
# 1920410              0.0                                       0.0
# 19702316748          0.0                                       0.0
# 2d4nk4m3             0.0                                       0.0
# ...                  ...                                       ...
# wswanderer81         0.0                                       0.0
# wyvaud               0.0                                       0.0
# xexilex              0.0                                       0.0
# xfluttersx           0.0                                       0.0
# yookobz              0.0                                       0.0
#
# item_name     1943 Megami Strike  3 Suicides of Paul Hamilton  \
# user_id
# 12549                        0.0                          0.0
# 13lazer                      0.0                          0.0
# 1920410                      0.0                          0.0
# 19702316748                  0.0                          0.0
# 2d4nk4m3                     0.0                          0.0
# ...                          ...                          ...
# wswanderer81                 0.0                          0.0
# wyvaud                       0.0                          0.0
# xexilex                      0.0                          0.0
# xfluttersx                   0.0                          0.0
# yookobz                      0.0                          0.0
#
# item_name     3030 Deathwar Redux  3d Bridges  500 MILES  \
# user_id
# 12549                         0.0         0.0        0.0
# 13lazer                       0.0         0.0        0.0
# 1920410                       0.0         0.0        0.0
# 19702316748                   0.0         0.0        0.0
# 2d4nk4m3                      0.0         0.0        0.0
# ...                           ...         ...        ...
# wswanderer81                  0.0         0.0        0.0
# wyvaud                        0.0         0.0        0.0
# xexilex                       0.0         0.0        0.0
# xfluttersx                    0.0         0.0        0.0
# yookobz                       0.0         0.0        0.0
#
# item_name     688(I) Hunter/Killer  7 Days to Die  ...  \
# user_id                                            ...
# 12549                          0.0            0.0  ...
# 13lazer                        0.0            0.0  ...
# 1920410                        0.0            0.0  ...
# 19702316748                    0.0            0.0  ...
# 2d4nk4m3                       0.0            0.0  ...
# ...                            ...            ...  ...
# wswanderer81                   0.0            0.0  ...
# wyvaud                         0.0            0.0  ...
# xexilex                        0.0            0.0  ...
# xfluttersx                     0.0            0.0  ...
# yookobz                        0.0            0.0  ...
#
# item_name     Zuma's Revenge! - Adventure  [the Sequence]  \
# user_id
# 12549                                 0.0             0.0
# 13lazer                               0.0             0.0
# 1920410                               0.0             0.0
# 19702316748                           0.0             0.0
# 2d4nk4m3                              0.0             0.0
# ...                                   ...             ...
# wswanderer81                          0.0             0.0
# wyvaud                                0.0             0.0
# xexilex                               0.0             0.0
# xfluttersx                            0.0             0.0
# yookobz                               0.0             0.0
#
# item_name     a Family of Grave Diggers  eXceed - Gun Bullet Children  \
# user_id
# 12549                               0.0                           0.0
# 13lazer                             0.0                           0.0
# 1920410                             0.0                           0.0
# 19702316748                         0.0                           0.0
# 2d4nk4m3                            0.0                           0.0
# ...                                 ...                           ...
# wswanderer81                        0.0                           0.0
# wyvaud                              0.0                           0.0
# xexilex                             0.0                           0.0
# xfluttersx                          0.0                           0.0
# yookobz                             0.0                           0.0
#
# item_name     eXceed 2nd - Vampire REX  iPi Mocap Studio 2  \
# user_id
# 12549                              0.0                 0.0
# 13lazer                            0.0                 0.0
# 1920410                            0.0                 0.0
# 19702316748                        0.0                 0.0
# 2d4nk4m3                           0.0                 0.0
# ...                                ...                 ...
# wswanderer81                       0.0                 0.0
# wyvaud                             0.0                 0.0
# xexilex                            0.0                 0.0
# xfluttersx                         0.0                 0.0
# yookobz                            0.0                 0.0
#
# item_name     planetarian ~the reverie of a little planet~  sZone-Online  \
# user_id
# 12549                                                  0.0           0.0
# 13lazer                                                0.0           0.0
# 1920410                                                0.0           0.0
# 19702316748                                            0.0           0.0
# 2d4nk4m3                                               0.0           0.0
# ...                                                    ...           ...
# wswanderer81                                           0.0           0.0
# wyvaud                                                 0.0           0.0
# xexilex                                                0.0           0.0
# xfluttersx                                             0.0           0.0
# yookobz                                                0.0           0.0
#
# item_name     the static speaks my name  \
# user_id
# 12549                               0.0
# 13lazer                             0.0
# 1920410                             0.0
# 19702316748                         0.0
# 2d4nk4m3                            0.0
# ...                                 ...
# wswanderer81                        0.0
# wyvaud                              0.0
# xexilex                             0.0
# xfluttersx                          0.0
# yookobz                             0.0
#
# item_name     ä¸æå®æè
# ï¼Ranger of the jungleï¼
# user_id
# 12549                                               0.0
# 13lazer                                             0.0
# 1920410                                             0.0
# 19702316748                                         0.0
# 2d4nk4m3                                            0.0
# ...                                                 ...
# wswanderer81                                        0.0
# wyvaud                                              0.0
# xexilex                                             0.0
# xfluttersx                                          0.0
# yookobz                                             0.0
#
# [398 rows x 1368 columns]

# %%
# Se normaliza la matriz pivote con la fórmula de normalización
piv_table_norm = piv_table.apply(lambda x: (x-np.mean(x))/(np.max(x)-np.min(x)), axis=1)

# %%
# Se transpone la matriz, para tener juegos en filas
piv_table_norm.fillna(0, inplace=True)
piv_table_norm = piv_table_norm.T
# Se manteniene solo las columnas que tienen al menos un valor distinto de cero
piv_table_norm = piv_table_norm.loc[:, (piv_table_norm != 0).any(axis=0)]

# %%
piv_table_norm
# Out:
# user_id                                                12549   13lazer  \
# item_name
# 1... 2... 3... KICK IT! (Drop That Beat Like an... -0.000737 -0.000731
# 10,000,000                                         -0.000737 -0.000731
# 12 Labours of Hercules IV: Mother Nature           -0.000737 -0.000731
# 1943 Megami Strike                                 -0.000737 -0.000731
# 3 Suicides of Paul Hamilton                        -0.000737 -0.000731
# ...                                                      ...       ...
# iPi Mocap Studio 2                                 -0.000737 -0.000731
# planetarian ~the reverie of a little planet~       -0.000737 -0.000731
# sZone-Online                                       -0.000737 -0.000731
# the static speaks my name                          -0.000737 -0.000731
# ä¸æå®æè
# ï¼Ranger of the jungleï¼          -0.000737 -0.000731
#
# user_id                                              1920410  19702316748  \
# item_name
# 1... 2... 3... KICK IT! (Drop That Beat Like an... -0.000731    -0.000731
# 10,000,000                                         -0.000731    -0.000731
# 12 Labours of Hercules IV: Mother Nature           -0.000731    -0.000731
# 1943 Megami Strike                                 -0.000731    -0.000731
# 3 Suicides of Paul Hamilton                        -0.000731    -0.000731
# ...                                                      ...          ...
# iPi Mocap Studio 2                                 -0.000731    -0.000731
# planetarian ~the reverie of a little planet~       -0.000731    -0.000731
# sZone-Online                                       -0.000731    -0.000731
# the static speaks my name                          -0.000731    -0.000731
# ä¸æå®æè
# ï¼Ranger of the jungleï¼          -0.000731    -0.000731
#
# user_id                                             3021Daniel    3dster  \
# item_name
# 1... 2... 3... KICK IT! (Drop That Beat Like an...   -0.000731 -0.000731
# 10,000,000                                           -0.000731 -0.000731
# 12 Labours of Hercules IV: Mother Nature             -0.000731 -0.000731
# 1943 Megami Strike                                   -0.000731 -0.000731
# 3 Suicides of Paul Hamilton                          -0.000731 -0.000731
# ...                                                        ...       ...
# iPi Mocap Studio 2                                   -0.000731 -0.000731
# planetarian ~the reverie of a little planet~         -0.000731 -0.000731
# sZone-Online                                         -0.000731 -0.000731
# the static speaks my name                            -0.000731 -0.000731
# ä¸æå®æè
# ï¼Ranger of the jungleï¼            -0.000731 -0.000731
#
# user_id                                             666NeCrO  678rtv45  \
# item_name
# 1... 2... 3... KICK IT! (Drop That Beat Like an... -0.000731 -0.000731
# 10,000,000                                         -0.000731 -0.000731
# 12 Labours of Hercules IV: Mother Nature           -0.000731 -0.000731
# 1943 Megami Strike                                 -0.000731 -0.000731
# 3 Suicides of Paul Hamilton                        -0.000731 -0.000731
# ...                                                      ...       ...
# iPi Mocap Studio 2                                 -0.000731 -0.000731
# planetarian ~the reverie of a little planet~       -0.000731 -0.000731
# sZone-Online                                       -0.000731 -0.000731
# the static speaks my name                          -0.000731 -0.000731
# ä¸æå®æè
# ï¼Ranger of the jungleï¼          -0.000731 -0.000731
#
# user_id                                               750805  \
# item_name
# 1... 2... 3... KICK IT! (Drop That Beat Like an... -0.005126
# 10,000,000                                         -0.005126
# 12 Labours of Hercules IV: Mother Nature           -0.005126
# 1943 Megami Strike                                 -0.005126
# 3 Suicides of Paul Hamilton                        -0.005126
# ...                                                      ...
# iPi Mocap Studio 2                                 -0.005126
# planetarian ~the reverie of a little planet~       -0.005126
# sZone-Online                                       -0.005126
# the static speaks my name                          -0.005126
# ä¸æå®æè
# ï¼Ranger of the jungleï¼          -0.005126
#
# user_id                                             76561197961840584  ...  \
# item_name                                                              ...
# 1... 2... 3... KICK IT! (Drop That Beat Like an...          -0.000731  ...
# 10,000,000                                                  -0.000731  ...
# 12 Labours of Hercules IV: Mother Nature                    -0.000731  ...
# 1943 Megami Strike                                          -0.000731  ...
# 3 Suicides of Paul Hamilton                                 -0.000731  ...
# ...                                                               ...  ...
# iPi Mocap Studio 2                                          -0.000731  ...
# planetarian ~the reverie of a little planet~                -0.000731  ...
# sZone-Online                                                -0.000731  ...
# the static speaks my name                                   -0.000731  ...
# ä¸æå®æè
# ï¼Ranger of the jungleï¼                   -0.000731  ...
#
# user_id                                             thor2424  thugnificent  \
# item_name
# 1... 2... 3... KICK IT! (Drop That Beat Like an... -0.000731     -0.002151
# 10,000,000                                         -0.000731     -0.002151
# 12 Labours of Hercules IV: Mother Nature           -0.000731     -0.002151
# 1943 Megami Strike                                 -0.000731     -0.002151
# 3 Suicides of Paul Hamilton                        -0.000731     -0.002151
# ...                                                      ...           ...
# iPi Mocap Studio 2                                 -0.000731     -0.002151
# planetarian ~the reverie of a little planet~       -0.000731     -0.002151
# sZone-Online                                       -0.000731     -0.002151
# the static speaks my name                          -0.000731     -0.002151
# ä¸æå®æè
# ï¼Ranger of the jungleï¼          -0.000731     -0.002151
#
# user_id                                             turneddreamsintoanempire  \
# item_name
# 1... 2... 3... KICK IT! (Drop That Beat Like an...                 -0.000731
# 10,000,000                                                         -0.000731
# 12 Labours of Hercules IV: Mother Nature                           -0.000731
# 1943 Megami Strike                                                 -0.000731
# 3 Suicides of Paul Hamilton                                        -0.000731
# ...                                                                      ...
# iPi Mocap Studio 2                                                 -0.000731
# planetarian ~the reverie of a little planet~                       -0.000731
# sZone-Online                                                       -0.000731
# the static speaks my name                                          -0.000731
# ä¸æå®æè
# ï¼Ranger of the jungleï¼                          -0.000731
#
# user_id                                             ulramite  undietaker  \
# item_name
# 1... 2... 3... KICK IT! (Drop That Beat Like an... -0.000731   -0.000731
# 10,000,000                                         -0.000731   -0.000731
# 12 Labours of Hercules IV: Mother Nature           -0.000731   -0.000731
# 1943 Megami Strike                                 -0.000731   -0.000731
# 3 Suicides of Paul Hamilton                        -0.000731   -0.000731
# ...                                                      ...         ...
# iPi Mocap Studio 2                                 -0.000731   -0.000731
# planetarian ~the reverie of a little planet~       -0.000731   -0.000731
# sZone-Online                                       -0.000731   -0.000731
# the static speaks my name                          -0.000731   -0.000731
# ä¸æå®æè
# ï¼Ranger of the jungleï¼          -0.000731   -0.000731
#
# user_id                                             uradumbtit  virtueavatar  \
# item_name
# 1... 2... 3... KICK IT! (Drop That Beat Like an...   -0.000731     -0.000731
# 10,000,000                                           -0.000731     -0.000731
# 12 Labours of Hercules IV: Mother Nature             -0.000731     -0.000731
# 1943 Megami Strike                                   -0.000731     -0.000731
# 3 Suicides of Paul Hamilton                          -0.000731     -0.000731
# ...                                                        ...           ...
# iPi Mocap Studio 2                                   -0.000731     -0.000731
# planetarian ~the reverie of a little planet~         -0.000731     -0.000731
# sZone-Online                                         -0.000731     -0.000731
# the static speaks my name                            -0.000731     -0.000731
# ä¸æå®æè
# ï¼Ranger of the jungleï¼            -0.000731     -0.000731
#
# user_id                                             whodafuqisthisguilao  \
# item_name
# 1... 2... 3... KICK IT! (Drop That Beat Like an...             -0.000731
# 10,000,000                                                     -0.000731
# 12 Labours of Hercules IV: Mother Nature                       -0.000731
# 1943 Megami Strike                                             -0.000731
# 3 Suicides of Paul Hamilton                                    -0.000731
# ...                                                                  ...
# iPi Mocap Studio 2                                             -0.000731
# planetarian ~the reverie of a little planet~                   -0.000731
# sZone-Online                                                   -0.000731
# the static speaks my name                                      -0.000731
# ä¸æå®æè
# ï¼Ranger of the jungleï¼                      -0.000731
#
# user_id                                             wswanderer81  xfluttersx
# item_name
# 1... 2... 3... KICK IT! (Drop That Beat Like an...     -0.000731   -0.001349
# 10,000,000                                             -0.000731   -0.001349
# 12 Labours of Hercules IV: Mother Nature               -0.000731   -0.001349
# 1943 Megami Strike                                     -0.000731   -0.001349
# 3 Suicides of Paul Hamilton                            -0.000731   -0.001349
# ...                                                          ...         ...
# iPi Mocap Studio 2                                     -0.000731   -0.001349
# planetarian ~the reverie of a little planet~           -0.000731   -0.001349
# sZone-Online                                           -0.000731   -0.001349
# the static speaks my name                              -0.000731   -0.001349
# ä¸æå®æè
# ï¼Ranger of the jungleï¼              -0.000731   -0.001349
#
# [1368 rows x 288 columns]

# %%
# Reemplazar los valores infinitos con un valor específico
piv_table_norm.replace([np.inf, -np.inf], np.nan, inplace=True)
piv_table_norm.fillna(0, inplace=True)

# %%
# Se crea una tabla sparse que solo guarda valores distintos de cero y permite optimizar 
piv_sparse = sp.csr_matrix(piv_table_norm.values)
piv_sparse
# Out:
# <1368x288 sparse matrix of type '<class 'numpy.float64'>'
# 	with 393984 stored elements in Compressed Sparse Row format>

# %%
# Coseno de similitud aplicado a tablas de Item (nombre de juego) y User (id de usuario)
item_simil = cosine_similarity(piv_sparse)  # Item
user_simil = cosine_similarity(piv_sparse.T) # User

# %%
# Se ordenan en df
df_item_simil = pd.DataFrame(item_simil, index = piv_table_norm.index, columns = piv_table_norm.index) # Item
df_user_simil = pd.DataFrame(user_simil, index = piv_table_norm.columns, columns = piv_table_norm.columns) # User

# %%
df_item_simil
# Out:
# item_name                                           1... 2... 3... KICK IT! (Drop That Beat Like an Ugly Baby)  \
# item_name
# 1... 2... 3... KICK IT! (Drop That Beat Like an...                                           1.000000
# 10,000,000                                                                                  -0.021787
# 12 Labours of Hercules IV: Mother Nature                                                     0.045084
# 1943 Megami Strike                                                                          -0.049587
# 3 Suicides of Paul Hamilton                                                                  0.999980
# ...                                                                                               ...
# iPi Mocap Studio 2                                                                           0.999980
# planetarian ~the reverie of a little planet~                                                 0.753556
# sZone-Online                                                                                 0.046402
# the static speaks my name                                                                    0.345472
# ä¸æå®æè
# ï¼Ranger of the jungleï¼                                                    0.999980
#
# item_name                                           10,000,000  \
# item_name
# 1... 2... 3... KICK IT! (Drop That Beat Like an...   -0.021787
# 10,000,000                                            1.000000
# 12 Labours of Hercules IV: Mother Nature             -0.003502
# 1943 Megami Strike                                   -0.002640
# 3 Suicides of Paul Hamilton                          -0.021770
# ...                                                        ...
# iPi Mocap Studio 2                                   -0.021770
# planetarian ~the reverie of a little planet~         -0.017296
# sZone-Online                                         -0.003442
# the static speaks my name                            -0.009806
# ä¸æå®æè
# ï¼Ranger of the jungleï¼            -0.021770
#
# item_name                                           12 Labours of Hercules IV: Mother Nature  \
# item_name
# 1... 2... 3... KICK IT! (Drop That Beat Like an...                                  0.045084
# 10,000,000                                                                         -0.003502
# 12 Labours of Hercules IV: Mother Nature                                            1.000000
# 1943 Megami Strike                                                                 -0.006196
# 3 Suicides of Paul Hamilton                                                         0.045104
# ...                                                                                      ...
# iPi Mocap Studio 2                                                                  0.045104
# planetarian ~the reverie of a little planet~                                        0.033041
# sZone-Online                                                                       -0.000496
# the static speaks my name                                                           0.013151
# ä¸æå®æè
# ï¼Ranger of the jungleï¼                                           0.045104
#
# item_name                                           1943 Megami Strike  \
# item_name
# 1... 2... 3... KICK IT! (Drop That Beat Like an...           -0.049587
# 10,000,000                                                   -0.002640
# 12 Labours of Hercules IV: Mother Nature                     -0.006196
# 1943 Megami Strike                                            1.000000
# 3 Suicides of Paul Hamilton                                  -0.049560
# ...                                                                ...
# iPi Mocap Studio 2                                           -0.049560
# planetarian ~the reverie of a little planet~                 -0.038748
# sZone-Online                                                 -0.006122
# the static speaks my name                                    -0.020713
# ä¸æå®æè
# ï¼Ranger of the jungleï¼                    -0.049560
#
# item_name                                           3 Suicides of Paul Hamilton  \
# item_name
# 1... 2... 3... KICK IT! (Drop That Beat Like an...                     0.999980
# 10,000,000                                                            -0.021770
# 12 Labours of Hercules IV: Mother Nature                               0.045104
# 1943 Megami Strike                                                    -0.049560
# 3 Suicides of Paul Hamilton                                            1.000000
# ...                                                                         ...
# iPi Mocap Studio 2                                                     1.000000
# planetarian ~the reverie of a little planet~                           0.753577
# sZone-Online                                                           0.046421
# the static speaks my name                                              0.345495
# ä¸æå®æè
# ï¼Ranger of the jungleï¼                              1.000000
#
# item_name                                           3030 Deathwar Redux  \
# item_name
# 1... 2... 3... KICK IT! (Drop That Beat Like an...            -0.001374
# 10,000,000                                                    -0.001343
# 12 Labours of Hercules IV: Mother Nature                      -0.001524
# 1943 Megami Strike                                            -0.002090
# 3 Suicides of Paul Hamilton                                   -0.001364
# ...                                                                 ...
# iPi Mocap Studio 2                                            -0.001364
# planetarian ~the reverie of a little planet~                  -0.001545
# sZone-Online                                                  -0.001474
# the static speaks my name                                     -0.001797
# ä¸æå®æè
# ï¼Ranger of the jungleï¼                     -0.001364
#
# item_name                                           3d Bridges  500 MILES  \
# item_name
# 1... 2... 3... KICK IT! (Drop That Beat Like an...   -0.000383  -0.000383
# 10,000,000                                           -0.001317  -0.001317
# 12 Labours of Hercules IV: Mother Nature             -0.001428  -0.001428
# 1943 Megami Strike                                   -0.002064  -0.002064
# 3 Suicides of Paul Hamilton                          -0.000373  -0.000373
# ...                                                        ...        ...
# iPi Mocap Studio 2                                   -0.000373  -0.000373
# planetarian ~the reverie of a little planet~         -0.000780  -0.000780
# sZone-Online                                         -0.001379  -0.001379
# the static speaks my name                            -0.001408  -0.001408
# ä¸æå®æè
# ï¼Ranger of the jungleï¼            -0.000373  -0.000373
#
# item_name                                           688(I) Hunter/Killer  \
# item_name
# 1... 2... 3... KICK IT! (Drop That Beat Like an...              0.519988
# 10,000,000                                                     -0.013168
# 12 Labours of Hercules IV: Mother Nature                        0.021487
# 1943 Megami Strike                                             -0.028676
# 3 Suicides of Paul Hamilton                                     0.520012
# ...                                                                  ...
# iPi Mocap Studio 2                                              0.520012
# planetarian ~the reverie of a little planet~                    0.391174
# sZone-Online                                                    0.022241
# the static speaks my name                                       0.177878
# ä¸æå®æè
# ï¼Ranger of the jungleï¼                       0.520012
#
# item_name                                           7 Days to Die  ...  \
# item_name                                                          ...
# 1... 2... 3... KICK IT! (Drop That Beat Like an...       0.515949  ...
# 10,000,000                                              -0.013881  ...
# 12 Labours of Hercules IV: Mother Nature                 0.020453  ...
# 1943 Megami Strike                                      -0.029734  ...
# 3 Suicides of Paul Hamilton                              0.515979  ...
# ...                                                           ...  ...
# iPi Mocap Studio 2                                       0.515979  ...
# planetarian ~the reverie of a little planet~             0.387833  ...
# sZone-Online                                             0.021231  ...
# the static speaks my name                                0.175712  ...
# ä¸æå®æè
# ï¼Ranger of the jungleï¼                0.515979  ...
#
# item_name                                           Zuma's Revenge! - Adventure  \
# item_name
# 1... 2... 3... KICK IT! (Drop That Beat Like an...                    -0.000383
# 10,000,000                                                            -0.001317
# 12 Labours of Hercules IV: Mother Nature                              -0.001428
# 1943 Megami Strike                                                    -0.002064
# 3 Suicides of Paul Hamilton                                           -0.000373
# ...                                                                         ...
# iPi Mocap Studio 2                                                    -0.000373
# planetarian ~the reverie of a little planet~                          -0.000780
# sZone-Online                                                          -0.001379
# the static speaks my name                                             -0.001408
# ä¸æå®æè
# ï¼Ranger of the jungleï¼                             -0.000373
#
# item_name                                           [the Sequence]  \
# item_name
# 1... 2... 3... KICK IT! (Drop That Beat Like an...       -0.767237
# 10,000,000                                               -0.022396
# 12 Labours of Hercules IV: Mother Nature                 -0.076221
# 1943 Megami Strike                                       -0.023430
# 3 Suicides of Paul Hamilton                              -0.766964
# ...                                                            ...
# iPi Mocap Studio 2                                       -0.766964
# planetarian ~the reverie of a little planet~             -0.592682
# sZone-Online                                             -0.075770
# the static speaks my name                                -0.302717
# ä¸æå®æè
# ï¼Ranger of the jungleï¼                -0.766964
#
# item_name                                           a Family of Grave Diggers  \
# item_name
# 1... 2... 3... KICK IT! (Drop That Beat Like an...                   0.999980
# 10,000,000                                                          -0.021770
# 12 Labours of Hercules IV: Mother Nature                             0.045104
# 1943 Megami Strike                                                  -0.049560
# 3 Suicides of Paul Hamilton                                          1.000000
# ...                                                                       ...
# iPi Mocap Studio 2                                                   1.000000
# planetarian ~the reverie of a little planet~                         0.753577
# sZone-Online                                                         0.046421
# the static speaks my name                                            0.345495
# ä¸æå®æè
# ï¼Ranger of the jungleï¼                            1.000000
#
# item_name                                           eXceed - Gun Bullet Children  \
# item_name
# 1... 2... 3... KICK IT! (Drop That Beat Like an...                     -0.024083
# 10,000,000                                                             -0.004415
# 12 Labours of Hercules IV: Mother Nature                               -0.006343
# 1943 Megami Strike                                                     -0.006569
# 3 Suicides of Paul Hamilton                                            -0.024047
# ...                                                                          ...
# iPi Mocap Studio 2                                                     -0.024047
# planetarian ~the reverie of a little planet~                           -0.019980
# sZone-Online                                                           -0.006190
# the static speaks my name                                              -0.013075
# ä¸æå®æè
# ï¼Ranger of the jungleï¼                              -0.024047
#
# item_name                                           eXceed 2nd - Vampire REX  \
# item_name
# 1... 2... 3... KICK IT! (Drop That Beat Like an...                 -0.008292
# 10,000,000                                                         -0.004760
# 12 Labours of Hercules IV: Mother Nature                           -0.005632
# 1943 Megami Strike                                                 -0.007354
# 3 Suicides of Paul Hamilton                                        -0.008256
# ...                                                                      ...
# iPi Mocap Studio 2                                                 -0.008256
# planetarian ~the reverie of a little planet~                       -0.008081
# sZone-Online                                                       -0.005458
# the static speaks my name                                          -0.007620
# ä¸æå®æè
# ï¼Ranger of the jungleï¼                          -0.008256
#
# item_name                                           iPi Mocap Studio 2  \
# item_name
# 1... 2... 3... KICK IT! (Drop That Beat Like an...            0.999980
# 10,000,000                                                   -0.021770
# 12 Labours of Hercules IV: Mother Nature                      0.045104
# 1943 Megami Strike                                           -0.049560
# 3 Suicides of Paul Hamilton                                   1.000000
# ...                                                                ...
# iPi Mocap Studio 2                                            1.000000
# planetarian ~the reverie of a little planet~                  0.753577
# sZone-Online                                                  0.046421
# the static speaks my name                                     0.345495
# ä¸æå®æè
# ï¼Ranger of the jungleï¼                     1.000000
#
# item_name                                           planetarian ~the reverie of a little planet~  \
# item_name
# 1... 2... 3... KICK IT! (Drop That Beat Like an...                                      0.753556
# 10,000,000                                                                             -0.017296
# 12 Labours of Hercules IV: Mother Nature                                                0.033041
# 1943 Megami Strike                                                                     -0.038748
# 3 Suicides of Paul Hamilton                                                             0.753577
# ...                                                                                          ...
# iPi Mocap Studio 2                                                                      0.753577
# planetarian ~the reverie of a little planet~                                            1.000000
# sZone-Online                                                                            0.034066
# the static speaks my name                                                               0.259498
# ä¸æå®æè
# ï¼Ranger of the jungleï¼                                               0.753577
#
# item_name                                           sZone-Online  \
# item_name
# 1... 2... 3... KICK IT! (Drop That Beat Like an...      0.046402
# 10,000,000                                             -0.003442
# 12 Labours of Hercules IV: Mother Nature               -0.000496
# 1943 Megami Strike                                     -0.006122
# 3 Suicides of Paul Hamilton                             0.046421
# ...                                                          ...
# iPi Mocap Studio 2                                      0.046421
# planetarian ~the reverie of a little planet~            0.034066
# sZone-Online                                            1.000000
# the static speaks my name                               0.953447
# ä¸æå®æè
# ï¼Ranger of the jungleï¼               0.046421
#
# item_name                                           the static speaks my name  \
# item_name
# 1... 2... 3... KICK IT! (Drop That Beat Like an...                   0.345472
# 10,000,000                                                          -0.009806
# 12 Labours of Hercules IV: Mother Nature                             0.013151
# 1943 Megami Strike                                                  -0.020713
# 3 Suicides of Paul Hamilton                                          0.345495
# ...                                                                       ...
# iPi Mocap Studio 2                                                   0.345495
# planetarian ~the reverie of a little planet~                         0.259498
# sZone-Online                                                         0.953447
# the static speaks my name                                            1.000000
# ä¸æå®æè
# ï¼Ranger of the jungleï¼                            0.345495
#
# item_name                                           ä¸æå®æè
# ï¼Ranger of the jungleï¼
# item_name
# 1... 2... 3... KICK IT! (Drop That Beat Like an...                                   0.999980
# 10,000,000                                                                          -0.021770
# 12 Labours of Hercules IV: Mother Nature                                             0.045104
# 1943 Megami Strike                                                                  -0.049560
# 3 Suicides of Paul Hamilton                                                          1.000000
# ...                                                                                       ...
# iPi Mocap Studio 2                                                                   1.000000
# planetarian ~the reverie of a little planet~                                         0.753577
# sZone-Online                                                                         0.046421
# the static speaks my name                                                            0.345495
# ä¸æå®æè
# ï¼Ranger of the jungleï¼                                            1.000000
#
# [1368 rows x 1368 columns]

# %%
df_user_simil
# Out:
# user_id                  12549   13lazer   1920410  19702316748  3021Daniel  \
# user_id
# 12549                 1.000000 -0.000738 -0.000738    -0.000738   -0.000738
# 13lazer              -0.000738  1.000000 -0.000732    -0.000732   -0.000732
# 1920410              -0.000738 -0.000732  1.000000    -0.000732   -0.000732
# 19702316748          -0.000738 -0.000732 -0.000732     1.000000   -0.000732
# 3021Daniel           -0.000738 -0.000732 -0.000732    -0.000732    1.000000
# ...                        ...       ...       ...          ...         ...
# uradumbtit           -0.000738 -0.000732 -0.000732    -0.000732   -0.000732
# virtueavatar         -0.000738 -0.000732 -0.000732    -0.000732   -0.000732
# whodafuqisthisguilao -0.000738 -0.000732 -0.000732    -0.000732   -0.000732
# wswanderer81         -0.000738 -0.000732 -0.000732    -0.000732   -0.000732
# xfluttersx           -0.001169 -0.001159 -0.001159    -0.001159   -0.001159
#
# user_id                 3dster  666NeCrO  678rtv45    750805  \
# user_id
# 12549                -0.000738 -0.000738 -0.000738 -0.002391
# 13lazer              -0.000732 -0.000732 -0.000732 -0.002371
# 1920410              -0.000732 -0.000732 -0.000732 -0.002371
# 19702316748          -0.000732 -0.000732 -0.000732 -0.002371
# 3021Daniel           -0.000732 -0.000732 -0.000732 -0.002371
# ...                        ...       ...       ...       ...
# uradumbtit           -0.000732 -0.000732 -0.000732 -0.002371
# virtueavatar         -0.000732 -0.000732 -0.000732 -0.002371
# whodafuqisthisguilao -0.000732 -0.000732 -0.000732 -0.002371
# wswanderer81         -0.000732 -0.000732 -0.000732 -0.002371
# xfluttersx           -0.001159 -0.001159 -0.001159 -0.003759
#
# user_id               76561197961840584  ...  thor2424  thugnificent  \
# user_id                                  ...
# 12549                         -0.000738  ... -0.000738     -0.001408
# 13lazer                       -0.000732  ... -0.000732     -0.001396
# 1920410                       -0.000732  ... -0.000732     -0.001396
# 19702316748                   -0.000732  ... -0.000732     -0.001396
# 3021Daniel                    -0.000732  ... -0.000732     -0.001396
# ...                                 ...  ...       ...           ...
# uradumbtit                    -0.000732  ... -0.000732     -0.001396
# virtueavatar                  -0.000732  ... -0.000732     -0.001396
# whodafuqisthisguilao          -0.000732  ... -0.000732     -0.001396
# wswanderer81                  -0.000732  ... -0.000732     -0.001396
# xfluttersx                    -0.001159  ... -0.001159     -0.002213
#
# user_id               turneddreamsintoanempire  ulramite  undietaker  \
# user_id
# 12549                                -0.000738 -0.000738   -0.000738
# 13lazer                              -0.000732 -0.000732   -0.000732
# 1920410                              -0.000732 -0.000732   -0.000732
# 19702316748                          -0.000732 -0.000732   -0.000732
# 3021Daniel                           -0.000732 -0.000732   -0.000732
# ...                                        ...       ...         ...
# uradumbtit                           -0.000732 -0.000732   -0.000732
# virtueavatar                         -0.000732 -0.000732   -0.000732
# whodafuqisthisguilao                 -0.000732 -0.000732   -0.000732
# wswanderer81                         -0.000732 -0.000732   -0.000732
# xfluttersx                           -0.001159 -0.001159   -0.001159
#
# user_id               uradumbtit  virtueavatar  whodafuqisthisguilao  \
# user_id
# 12549                  -0.000738     -0.000738             -0.000738
# 13lazer                -0.000732     -0.000732             -0.000732
# 1920410                -0.000732     -0.000732             -0.000732
# 19702316748            -0.000732     -0.000732             -0.000732
# 3021Daniel             -0.000732     -0.000732             -0.000732
# ...                          ...           ...                   ...
# uradumbtit              1.000000     -0.000732             -0.000732
# virtueavatar           -0.000732      1.000000             -0.000732
# whodafuqisthisguilao   -0.000732     -0.000732              1.000000
# wswanderer81           -0.000732     -0.000732             -0.000732
# xfluttersx             -0.001159     -0.001159             -0.001159
#
# user_id               wswanderer81  xfluttersx
# user_id
# 12549                    -0.000738   -0.001169
# 13lazer                  -0.000732   -0.001159
# 1920410                  -0.000732   -0.001159
# 19702316748              -0.000732   -0.001159
# 3021Daniel               -0.000732   -0.001159
# ...                            ...         ...
# uradumbtit               -0.000732   -0.001159
# virtueavatar             -0.000732   -0.001159
# whodafuqisthisguilao     -0.000732   -0.001159
# wswanderer81              1.000000   -0.001159
# xfluttersx               -0.001159    1.000000
#
# [288 rows x 288 columns]

# %% [markdown]
# Sistema de recomendación ITEM-ITEM:

# %%
# Los 5 juegos más recomendados por juego similar...
def recommended_games_item(game, df_item_simil):
    similar_games = {}
    count = 1
    for item in df_item_simil.sort_values(by=game, ascending=False).index[1:6]:
        similar_games[f"Recomendación {count}"] = item
        count += 1
    return similar_games

# %%
recommended_games_item("the static speaks my name", df_item_simil)
# Out:
# {'Recomendación 1': 'Among Ripples',
#  'Recomendación 2': 'Rustbucket Rumble',
#  'Recomendación 3': 'Istrolid',
#  'Recomendación 4': 'Curse of Mermos',
#  'Recomendación 5': 'Red Crucible: Firestorm'}

# %% [markdown]
# Sistema de recomendación USER-ITEM:

# %%
# Los 5 juegos más recomendados similares por usuario...
def similar_user_recs(user):
    
    # Se verifica si el usuario está presente en las columnas de piv_table_norm
    if user not in piv_table_norm.columns:
        return {'message': 'El Usuario no tiene datos disponibles {}'.format(user)}

    # Se obtienen los usuarios más similares 
    sim_users = df_user_simil.sort_values(by=user, ascending=False).index[1:11]

    best = []  
    most_common = {}  

    # Por cada usuario similar, encuentra el juego mejor calificado y lo agrega a la lista 'best'
    for i in sim_users:
        max_score = piv_table_norm.loc[:, i].max()
        best.append(piv_table_norm[piv_table_norm.loc[:, i] == max_score].index.tolist())

    # Se cuenta cuántas veces se recomienda cada juego
    for i in range(len(best)):
        for j in best[i]:
            if j in most_common:
                most_common[j] += 1
            else:
                most_common[j] = 1

    # Se ordenan los juegos de mayor recomendacion
    sorted_list = sorted(most_common.items(), key=operator.itemgetter(1), reverse=True)

    return dict(sorted_list[:5])

# %%
similar_user_recs("virtueavatar")
# Out:
# {'3d Bridges': 1, '500 MILES': 1, '8-Bit Hordes': 1, 'APOX': 1, 'ASRECorp': 1}

# %%
# Guardar dataframes a parquet
unique_item_ids.to_parquet('unique_item_ids.parquet')
user_name_time.to_parquet('user_name_time.parquet')
piv_table_norm.to_parquet('piv_table_norm.parquet')
df_item_simil.to_parquet('df_item_simil.parquet')
df_user_simil.to_parquet('df_user_simil.parquet')
